# %%
# %run -i src/segmentello/u_net_training.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\OneDrive\Desktop\AILAB_proj\NeuralTrasferello\src\segmentello\u_net_training.py:2
#       1 from data.config import *
# ----> 2 from dataset import CoarseMaskDataset
#       3 from u_net_attention_model import Coarse2FineUNet
#       4 from torch.utils.data import DataLoader, random_split
#
# File ~\OneDrive\Desktop\AILAB_proj\NeuralTrasferello\src\segmentello\dataset.py:5
#       3 import torch
#       4 from torch.utils.data import Dataset
# ----> 5 import torchvision.transforms as T
#       6 import numpy as np
#       7 import cv2
#
# File c:\Users\miche\OneDrive\Desktop\AILAB_proj\NeuralTrasferello\venv\Lib\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
# ...
